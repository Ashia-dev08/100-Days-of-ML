# %%
import pandas as pd

# %%
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
import numpy as np

# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.2.5-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.2.5-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.6 MB 4.3 MB/s eta 0:00:03
#    ------- -------------------------------- 2.4/12.6 MB 5.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.6 MB 5.9 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/12.6 MB 5.9 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.6 MB 5.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.6 MB 5.6 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.6 MB 5.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.6 MB 5.7 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.6 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 5.1 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.2.5
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #0. preprocess +EDA+Feature Selection
# #1. Extract input and output cols
# #2 Scale the value
# #3 train the split
# #4 train the model
# #5 Evaluate the model/model selction
# #6 Deploy the model

# %%
#0. preprocess +EDA+Feature Selection
#1. Extract input and output cols
#2 Scale the value
#3 train the split
#4 train the model
#5 Evaluate the model/model selction
#6 Deploy the model**

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("placement.csv")
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df=df.iloc[:,1:]
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]

# %%
X.head()
# Out:
#    cgpa     iq
# 0   6.8  123.0
# 1   5.9  106.0
# 2   5.3  121.0
# 3   7.4  132.0
# 4   5.8  142.0

# %%
y= df.iloc[:,-1]
y.shape
# Out:
# (100,)

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\flask demo\venv\campus\lib\site-packages (from scikit-learn) (2.2.5)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp313-cp313-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 2.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/11.1 MB 2.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.1 MB 2.7 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.1 MB 3.1 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.1 MB 3.3 MB/s eta 0:00:03
#    --------------- ------------------------ 4.2/11.1 MB 3.5 MB/s eta 0:00:02
#    ------------------ --------------------- 5.2/11.1 MB 3.6 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.1 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 7.1/11.1 MB 3.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.9/11.1 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.1 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 2.6 MB/s eta 0:00:00
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Downloading scipy-1.15.3-cp313-cp313-win_amd64.whl (41.0 MB)
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#     --------------------------------------- 0.8/41.0 MB 3.1 MB/s eta 0:00:13
#    - -------------------------------------- 1.6/41.0 MB 3.7 MB/s eta 0:00:11
#    -- ------------------------------------- 2.4/41.0 MB 3.8 MB/s eta 0:00:11
#    --- ------------------------------------ 3.1/41.0 MB 3.8 MB/s eta 0:00:10
#    --- ------------------------------------ 3.9/41.0 MB 3.7 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.7/41.0 MB 3.7 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.5/41.0 MB 3.7 MB/s eta 0:00:10
#    ------ --------------------------------- 6.3/41.0 MB 3.8 MB/s eta 0:00:10
#    ------ --------------------------------- 7.1/41.0 MB 3.7 MB/s eta 0:00:10
#    ------- -------------------------------- 8.1/41.0 MB 3.8 MB/s eta 0:00:09
#    -------- ------------------------------- 8.9/41.0 MB 3.9 MB/s eta 0:00:09
#    --------- ------------------------------ 10.0/41.0 MB 3.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.7/41.0 MB 3.9 MB/s eta 0:00:08
#    ----------- ---------------------------- 11.8/41.0 MB 4.0 MB/s eta 0:00:08
#    ------------ --------------------------- 12.6/41.0 MB 4.0 MB/s eta 0:00:08
#    ------------- -------------------------- 13.6/41.0 MB 4.0 MB/s eta 0:00:07
#    -------------- ------------------------- 14.4/41.0 MB 4.0 MB/s eta 0:00:07
#    -------------- ------------------------- 15.2/41.0 MB 4.0 MB/s eta 0:00:07
#    --------------- ------------------------ 16.0/41.0 MB 4.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.5/41.0 MB 3.9 MB/s eta 0:00:07
#    ---------------- ----------------------- 17.3/41.0 MB 3.9 MB/s eta 0:00:07
#    ----------------- ---------------------- 18.1/41.0 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 18.9/41.0 MB 3.9 MB/s eta 0:00:06
#    ------------------- -------------------- 19.9/41.0 MB 3.9 MB/s eta 0:00:06
#    -------------------- ------------------- 20.7/41.0 MB 3.9 MB/s eta 0:00:06
#    -------------------- ------------------- 21.5/41.0 MB 3.9 MB/s eta 0:00:05
#    --------------------- ------------------ 22.3/41.0 MB 3.9 MB/s eta 0:00:05
#    ---------------------- ----------------- 23.1/41.0 MB 3.9 MB/s eta 0:00:05
#    ----------------------- ---------------- 23.9/41.0 MB 3.9 MB/s eta 0:00:05
#    ------------------------ --------------- 24.6/41.0 MB 3.9 MB/s eta 0:00:05
#    ------------------------- -------------- 25.7/41.0 MB 3.9 MB/s eta 0:00:04
#    ------------------------- -------------- 26.5/41.0 MB 3.9 MB/s eta 0:00:04
#    -------------------------- ------------- 27.3/41.0 MB 3.9 MB/s eta 0:00:04
#    --------------------------- ------------ 28.0/41.0 MB 3.9 MB/s eta 0:00:04
#    ---------------------------- ----------- 28.8/41.0 MB 3.9 MB/s eta 0:00:04
#    ----------------------------- ---------- 29.9/41.0 MB 3.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 30.4/41.0 MB 3.9 MB/s eta 0:00:03
#    ------------------------------ --------- 31.2/41.0 MB 3.9 MB/s eta 0:00:03
#    ------------------------------ --------- 31.7/41.0 MB 3.8 MB/s eta 0:00:03
#    ------------------------------- -------- 32.5/41.0 MB 3.8 MB/s eta 0:00:03
#    -------------------------------- ------- 33.0/41.0 MB 3.8 MB/s eta 0:00:03
#    -------------------------------- ------- 33.6/41.0 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 34.3/41.0 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/41.0 MB 3.7 MB/s eta 0:00:02
#    ------------------------------------ --- 37.0/41.0 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 38.0/41.0 MB 2.9 MB/s eta 0:00:02
#    -------------------------------------- - 39.1/41.0 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  40.1/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 41.0/41.0 MB 2.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------------------------------------- 0/4 [threadpoolctl]
#    ---------------------------------------- 0/4 [threadpoolctl]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.0 scikit-learn-1.6.1 scipy-1.15.3 threadpoolctl-3.6.0

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
y_train
# Out:
# 74    1
# 26    1
# 43    1
# 52    1
# 48    1
#      ..
# 1     0
# 62    0
# 91    1
# 14    0
# 82    1
# Name: placement, Length: 90, dtype: int64

# %%
X_train
# Out:
#     cgpa     iq
# 74   6.7  154.0
# 26   7.0  199.0
# 43   6.8  141.0
# 52   7.0  175.0
# 48   6.6  138.0
# ..   ...    ...
# 1    5.9  106.0
# 62   6.0  102.0
# 91   7.5  158.0
# 14   6.1  103.0
# 82   6.5   37.0
#
# [90 rows x 2 columns]

# %%
y_test
# Out:
# 32    1
# 8     0
# 53    1
# 88    0
# 27    1
# 37    1
# 5     1
# 50    0
# 96    0
# 83    1
# Name: placement, dtype: int64

# %%
y_train
# Out:
# 74    1
# 26    1
# 43    1
# 52    1
# 48    1
#      ..
# 1     0
# 62    0
# 91    1
# 14    0
# 82    1
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# First create an instance
scaler = StandardScaler()  

# Then call method on instance with your data
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.68585599,  0.83379665],
#        [ 0.96516386,  2.02283764],
#        [ 0.77895862,  0.49029592],
#        [ 0.96516386,  1.38868245],
#        [ 0.59275337,  0.41102652],
#        [-0.89688861, -0.11743615],
#        [ 0.22034288, -0.24955181],
#        [-1.82791484, -1.25363088],
#        [-0.24517024,  0.54314218],
#        [ 1.24447173,  0.38460338],
#        [ 1.8961901 , -1.14793834],
#        [-0.61758074, -0.22312868],
#        [ 0.03413763,  0.70168098],
#        [ 0.49965075,  0.99233545],
#        [ 0.3134455 ,  0.14679518],
#        [-0.80378598,  1.41510558],
#        [-0.61758074, -0.03816675],
#        [ 0.96516386, -1.54428534],
#        [ 1.43067698, -1.62355474],
#        [ 1.24447173, -1.91420921],
#        [ 0.77895862,  0.01467952],
#        [ 1.98929272,  1.15087425],
#        [ 0.3134455 , -0.51378315],
#        [-0.89688861, -1.57070847],
#        [-0.52447811, -0.40809061],
#        [ 0.3134455 ,  0.12037205],
#        [-0.71068336, -0.32882121],
#        [ 0.77895862, -0.85728388],
#        [ 0.12724025,  0.25248772],
#        [ 0.03413763, -2.04632487],
#        [-0.52447811,  0.43744965],
#        [ 2.36170322, -0.06458988],
#        [-1.08309385, -0.27597495],
#        [-1.17619648, -1.86136294],
#        [-0.80378598,  0.14679518],
#        [-1.82791484, -0.59305255],
#        [-0.89688861, -0.83086074],
#        [-0.24517024,  1.23014365],
#        [ 0.40654812,  0.49029592],
#        [ 0.59275337, -0.06458988],
#        [-0.80378598, -1.49143907],
#        [-0.15206762,  0.51671905],
#        [-0.15206762,  1.15087425],
#        [ 1.70998485, -0.22312868],
#        [-1.2692991 ,  0.62241158],
#        [ 0.40654812, -0.17028241],
#        [ 0.96516386, -0.27597495],
#        [ 0.03413763, -1.49143907],
#        [ 0.49965075, -0.85728388],
#        [ 1.24447173, -0.96297641],
#        [-1.08309385,  1.07160485],
#        [-1.08309385,  0.49029592],
#        [ 0.77895862, -0.27597495],
#        [-0.98999123,  1.94356824],
#        [-1.17619648, -0.03816675],
#        [-0.24517024,  0.46387278],
#        [-0.98999123, -1.62355474],
#        [ 1.24447173, -0.17028241],
#        [ 1.52377961,  0.14679518],
#        [-1.54860697,  2.04926078],
#        [-1.92101747, -0.35524435],
#        [-0.71068336,  2.68341597],
#        [-0.24517024,  0.25248772],
#        [-2.47963321,  1.60006751],
#        [-1.17619648, -0.93655328],
#        [ 0.12724025, -1.51786221],
#        [ 1.33757436,  0.25248772],
#        [-0.98999123,  0.30533398],
#        [ 1.52377961, -0.88370701],
#        [ 0.49965075,  0.19964145],
#        [ 1.05826649,  0.75452725],
#        [-0.71068336, -0.85728388],
#        [-0.98999123, -0.06458988],
#        [-0.52447811,  0.33175712],
#        [-0.71068336,  0.25248772],
#        [-0.71068336,  1.01875858],
#        [-0.52447811, -0.22312868],
#        [-0.98999123,  0.86021978],
#        [-1.08309385,  1.23014365],
#        [ 0.87206124,  0.43744965],
#        [ 0.68585599,  1.57364438],
#        [ 0.87206124,  0.41102652],
#        [-0.98999123,  0.75452725],
#        [ 0.87206124, -0.69874508],
#        [ 0.12724025, -1.09509208],
#        [-0.05896499, -0.43451375],
#        [ 0.03413763, -0.54020628],
#        [ 1.43067698,  0.93948918],
#        [ 0.12724025, -0.51378315],
#        [ 0.49965075, -2.25770994]])

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.96516386,  0.43744965],
#        [ 0.12724025,  0.88664291],
#        [ 2.17549797,  1.20372051],
#        [-1.45550435,  0.70168098],
#        [ 0.03413763,  0.04110265],
#        [ 1.98929272,  0.70168098],
#        [ 1.05826649, -1.96705547],
#        [-2.29342796,  2.92122417],
#        [-1.45550435, -2.12559427],
#        [ 1.43067698,  0.19964145]])

# %%
from sklearn.linear_model import LogisticRegression
cif = LogisticRegression()

# %%
#
cif.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=cif.predict(X_test)

# %%
y_test
# Out:
# 32    1
# 8     0
# 53    1
# 88    0
# 27    1
# 37    1
# 5     1
# 50    0
# 96    0
# 83    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\flask demo\venv\campus\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\flask demo\venv\campus\lib\site-packages (from mlxtend) (2.2.5)
# Requirement already satisfied: pandas>=0.24.2 in c:\flask demo\venv\campus\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\flask demo\venv\campus\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\flask demo\venv\campus\lib\site-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\flask demo\venv\campus\lib\site-packages (from mlxtend) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\flask demo\venv\campus\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\flask demo\venv\campus\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\flask demo\venv\campus\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\flask demo\venv\campus\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\flask demo\venv\campus\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\flask demo\venv\campus\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\flask demo\venv\campus\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\flask demo\venv\campus\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\flask demo\venv\campus\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\flask demo\venv\campus\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\flask demo\venv\campus\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\flask demo\venv\campus\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ----------------------- ---------------- 0.8/1.4 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=cif, legend=2)
# Out:
# <Axes: >

# %%
import pickle
pickle.dump(cif,open('model.pkl','wb'))
